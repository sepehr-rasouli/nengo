# %% [markdown]
# # NEF summary
#
# The Neural Engineering Framework (NEF)
# is one set of theoretical methods that are used in
# Nengo for constructing neural models.
# The NEF is based on [Eliasmith & Anderson's (2003) book](
# https://mitpress.mit.edu/books/neural-engineering) from MIT Press.
# This notebook introduces the three main principles
# discussed in that book and implemented in Nengo.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import nengo
from nengo.dists import Uniform
from nengo.processes import WhiteSignal
from nengo.utils.ensemble import tuning_curves
from nengo.utils.ipython import hide_input
from nengo.utils.matplotlib import rasterplot


def aligned(n_neurons, radius=0.9):
    intercepts = np.linspace(-radius, radius, n_neurons)
    encoders = np.tile([[1], [-1]], (n_neurons // 2, 1))
    intercepts *= encoders[:, 0]
    return intercepts, encoders


hide_input()
# Out:
#         <a id="171283049" href="javascript:toggle_input_171283049()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_171283049;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_171283049 = document.getElementById("171283049");
#                 var cell = link_171283049;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_171283049;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_171283049 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_171283049 = cell.previousElementSibling;
#                 }
#                 input_171283049.style.display = "none"; // hide
#
#                 toggle_input_171283049 = function() {
#                     if (input_171283049.style.display == "none") {
#                         input_171283049.style.display = ""; // show
#                         link_171283049.innerHTML = "Hide Input";
#                     } else {
#                         input_171283049.style.display = "none"; // hide
#                         link_171283049.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_171283049 = $("a[id='171283049']");
#                 var cell_171283049 = link_171283049.parents("div.cell:first");
#                 if (cell_171283049.length == 0) {
#                     cell_171283049 = link_171283049.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_171283049 = cell_171283049.children("div.input");
#                 if (input_171283049.length == 0) {
#                     input_171283049 = cell_171283049.prev("div.nbinput");
#                 }
#                 input_171283049.hide();
#
#                 toggle_input_171283049 = function() {
#                     if (input_171283049.is(':hidden')) {
#                         input_171283049.slideDown();
#                         link_171283049[0].innerHTML = "Hide Input";
#                     } else {
#                         input_171283049.slideUp();
#                         link_171283049[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 1: Representation
#
# ### Encoding
#
# Neural populations represent time-varying signals
# through their spiking responses.
# A signal is a vector of real numbers of arbitrary length.
# This example is a 1D signal going from -1 to 1 in 1 second.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1.0)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], lw=2)
plt.title("Input signal")
plt.xlabel("Time (s)")
plt.xlim(0, 1);
hide_input()
# Out:
#         <a id="975674159" href="javascript:toggle_input_975674159()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_975674159;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_975674159 = document.getElementById("975674159");
#                 var cell = link_975674159;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_975674159;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_975674159 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_975674159 = cell.previousElementSibling;
#                 }
#                 input_975674159.style.display = "none"; // hide
#
#                 toggle_input_975674159 = function() {
#                     if (input_975674159.style.display == "none") {
#                         input_975674159.style.display = ""; // show
#                         link_975674159.innerHTML = "Hide Input";
#                     } else {
#                         input_975674159.style.display = "none"; // hide
#                         link_975674159.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_975674159 = $("a[id='975674159']");
#                 var cell_975674159 = link_975674159.parents("div.cell:first");
#                 if (cell_975674159.length == 0) {
#                     cell_975674159 = link_975674159.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_975674159 = cell_975674159.children("div.input");
#                 if (input_975674159.length == 0) {
#                     input_975674159 = cell_975674159.prev("div.nbinput");
#                 }
#                 input_975674159.hide();
#
#                 toggle_input_975674159 = function() {
#                     if (input_975674159.is(':hidden')) {
#                         input_975674159.slideDown();
#                         link_975674159[0].innerHTML = "Hide Input";
#                     } else {
#                         input_975674159.slideUp();
#                         link_975674159[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# These signals drive neural populations
# based on each neuron's *tuning curve*
# (which is similar to the current-frequency curve,
# if you're familiar with that).
#
# The tuning curve describes how much
# a particular neuron will fire as a function of the input signal.

# %%
intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
with model:
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders)

# %%
with nengo.Simulator(model) as sim:
    eval_points, activities = tuning_curves(A, sim)

plt.figure()
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)");
hide_input()
# Out:
#         <a id="2140262184" href="javascript:toggle_input_2140262184()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2140262184;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2140262184 = document.getElementById("2140262184");
#                 var cell = link_2140262184;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2140262184;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_2140262184 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_2140262184 = cell.previousElementSibling;
#                 }
#                 input_2140262184.style.display = "none"; // hide
#
#                 toggle_input_2140262184 = function() {
#                     if (input_2140262184.style.display == "none") {
#                         input_2140262184.style.display = ""; // show
#                         link_2140262184.innerHTML = "Hide Input";
#                     } else {
#                         input_2140262184.style.display = "none"; // hide
#                         link_2140262184.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2140262184 = $("a[id='2140262184']");
#                 var cell_2140262184 = link_2140262184.parents("div.cell:first");
#                 if (cell_2140262184.length == 0) {
#                     cell_2140262184 = link_2140262184.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_2140262184 = cell_2140262184.children("div.input");
#                 if (input_2140262184.length == 0) {
#                     input_2140262184 = cell_2140262184.prev("div.nbinput");
#                 }
#                 input_2140262184.hide();
#
#                 toggle_input_2140262184 = function() {
#                     if (input_2140262184.is(':hidden')) {
#                         input_2140262184.slideDown();
#                         link_2140262184[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2140262184.slideUp();
#                         link_2140262184[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# We can drive these neurons with our input signal
# and observe their spiking activity over time.

# %%
with model:
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
ax = plt.subplot(1, 1, 1)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
ax.set_xlim(0, 1)
ax.set_ylabel('Neuron')
ax.set_xlabel('Time (s)');
hide_input()
# Out:
#         <a id="754516226" href="javascript:toggle_input_754516226()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_754516226;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_754516226 = document.getElementById("754516226");
#                 var cell = link_754516226;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_754516226;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_754516226 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_754516226 = cell.previousElementSibling;
#                 }
#                 input_754516226.style.display = "none"; // hide
#
#                 toggle_input_754516226 = function() {
#                     if (input_754516226.style.display == "none") {
#                         input_754516226.style.display = ""; // show
#                         link_754516226.innerHTML = "Hide Input";
#                     } else {
#                         input_754516226.style.display = "none"; // hide
#                         link_754516226.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_754516226 = $("a[id='754516226']");
#                 var cell_754516226 = link_754516226.parents("div.cell:first");
#                 if (cell_754516226.length == 0) {
#                     cell_754516226 = link_754516226.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_754516226 = cell_754516226.children("div.input");
#                 if (input_754516226.length == 0) {
#                     input_754516226 = cell_754516226.prev("div.nbinput");
#                 }
#                 input_754516226.hide();
#
#                 toggle_input_754516226 = function() {
#                     if (input_754516226.is(':hidden')) {
#                         input_754516226.slideDown();
#                         link_754516226[0].innerHTML = "Hide Input";
#                     } else {
#                         input_754516226.slideUp();
#                         link_754516226[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ### Decoding
#
# We can estimate the input signal
# originally encoded by decoding the pattern of spikes.
# To do this, we first filter the spike train
# with a temporal filter that accounts for
# postsynaptic current (PSC) activity.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
    A = nengo.Ensemble(8, dimensions=1,
                       intercepts=intercepts,
                       max_rates=Uniform(80, 100),
                       encoders=encoders)
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

scale = 180
plt.figure()
for i in range(A.n_neurons):
    plt.plot(sim.trange(), sim.data[A_spikes][:, i] - i * scale)
plt.xlim(0, 1)
plt.ylim(scale * (-A.n_neurons + 1), scale)
plt.ylabel("Neuron")
plt.yticks(
    np.arange(scale / 1.8, (-A.n_neurons + 1) * scale, -scale),
    np.arange(A.n_neurons))
hide_input()
# Out:
#         <a id="355721289" href="javascript:toggle_input_355721289()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_355721289;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_355721289 = document.getElementById("355721289");
#                 var cell = link_355721289;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_355721289;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_355721289 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_355721289 = cell.previousElementSibling;
#                 }
#                 input_355721289.style.display = "none"; // hide
#
#                 toggle_input_355721289 = function() {
#                     if (input_355721289.style.display == "none") {
#                         input_355721289.style.display = ""; // show
#                         link_355721289.innerHTML = "Hide Input";
#                     } else {
#                         input_355721289.style.display = "none"; // hide
#                         link_355721289.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_355721289 = $("a[id='355721289']");
#                 var cell_355721289 = link_355721289.parents("div.cell:first");
#                 if (cell_355721289.length == 0) {
#                     cell_355721289 = link_355721289.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_355721289 = cell_355721289.children("div.input");
#                 if (input_355721289.length == 0) {
#                     input_355721289 = cell_355721289.prev("div.nbinput");
#                 }
#                 input_355721289.hide();
#
#                 toggle_input_355721289 = function() {
#                     if (input_355721289.is(':hidden')) {
#                         input_355721289.slideDown();
#                         link_355721289[0].innerHTML = "Hide Input";
#                     } else {
#                         input_355721289.slideUp();
#                         link_355721289[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Then we mulitply those filtered spike trains
# with decoding weights and sum them together
# to give an estimate of the input based on the spikes.
#
# The decoding weights are determined
# by minimizing the squared difference
# between the decoded estimate and the actual input signal.

# %%
with model:
    A_probe = nengo.Probe(A, synapse=0.01)  # 10ms PSC filter

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded estimate")
plt.legend(loc="best")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="1568711347" href="javascript:toggle_input_1568711347()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1568711347;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1568711347 = document.getElementById("1568711347");
#                 var cell = link_1568711347;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1568711347;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1568711347 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1568711347 = cell.previousElementSibling;
#                 }
#                 input_1568711347.style.display = "none"; // hide
#
#                 toggle_input_1568711347 = function() {
#                     if (input_1568711347.style.display == "none") {
#                         input_1568711347.style.display = ""; // show
#                         link_1568711347.innerHTML = "Hide Input";
#                     } else {
#                         input_1568711347.style.display = "none"; // hide
#                         link_1568711347.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1568711347 = $("a[id='1568711347']");
#                 var cell_1568711347 = link_1568711347.parents("div.cell:first");
#                 if (cell_1568711347.length == 0) {
#                     cell_1568711347 = link_1568711347.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1568711347 = cell_1568711347.children("div.input");
#                 if (input_1568711347.length == 0) {
#                     input_1568711347 = cell_1568711347.prev("div.nbinput");
#                 }
#                 input_1568711347.hide();
#
#                 toggle_input_1568711347 = function() {
#                     if (input_1568711347.is(':hidden')) {
#                         input_1568711347.slideDown();
#                         link_1568711347[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1568711347.slideUp();
#                         link_1568711347[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# The accuracy of the decoded estimate increases
# as the number of neurons increases.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(15, 3.5))

plt.subplot(1, 3, 1)
eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")

ax = plt.subplot(1, 3, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")

plt.subplot(1, 3, 3)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="148420917" href="javascript:toggle_input_148420917()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_148420917;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_148420917 = document.getElementById("148420917");
#                 var cell = link_148420917;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_148420917;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_148420917 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_148420917 = cell.previousElementSibling;
#                 }
#                 input_148420917.style.display = "none"; // hide
#
#                 toggle_input_148420917 = function() {
#                     if (input_148420917.style.display == "none") {
#                         input_148420917.style.display = ""; // show
#                         link_148420917.innerHTML = "Hide Input";
#                     } else {
#                         input_148420917.style.display = "none"; // hide
#                         link_148420917.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_148420917 = $("a[id='148420917']");
#                 var cell_148420917 = link_148420917.parents("div.cell:first");
#                 if (cell_148420917.length == 0) {
#                     cell_148420917 = link_148420917.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_148420917 = cell_148420917.children("div.input");
#                 if (input_148420917.length == 0) {
#                     input_148420917 = cell_148420917.prev("div.nbinput");
#                 }
#                 input_148420917.hide();
#
#                 toggle_input_148420917 = function() {
#                     if (input_148420917.is(':hidden')) {
#                         input_148420917.slideDown();
#                         link_148420917[0].innerHTML = "Hide Input";
#                     } else {
#                         input_148420917.slideUp();
#                         link_148420917[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Any smooth signal can be encoded and decoded.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1739309655" href="javascript:toggle_input_1739309655()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1739309655;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1739309655 = document.getElementById("1739309655");
#                 var cell = link_1739309655;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1739309655;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1739309655 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1739309655 = cell.previousElementSibling;
#                 }
#                 input_1739309655.style.display = "none"; // hide
#
#                 toggle_input_1739309655 = function() {
#                     if (input_1739309655.style.display == "none") {
#                         input_1739309655.style.display = ""; // show
#                         link_1739309655.innerHTML = "Hide Input";
#                     } else {
#                         input_1739309655.style.display = "none"; // hide
#                         link_1739309655.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1739309655 = $("a[id='1739309655']");
#                 var cell_1739309655 = link_1739309655.parents("div.cell:first");
#                 if (cell_1739309655.length == 0) {
#                     cell_1739309655 = link_1739309655.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1739309655 = cell_1739309655.children("div.input");
#                 if (input_1739309655.length == 0) {
#                     input_1739309655 = cell_1739309655.prev("div.nbinput");
#                 }
#                 input_1739309655.hide();
#
#                 toggle_input_1739309655 = function() {
#                     if (input_1739309655.is(':hidden')) {
#                         input_1739309655.slideDown();
#                         link_1739309655[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1739309655.slideUp();
#                         link_1739309655[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 2: Transformation
#
# Encoding and decoding allow us to encode signals over time,
# and decode transformations of those signals.
#
# In fact, we can decode arbitrary transformations of the input signal,
# not just the signal itself (as in the previous example).
#
# Let's decode the square of our white noise input.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input, )
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    Asquare = nengo.Node(size_in=1)
    nengo.Connection(input, A)
    nengo.Connection(A, Asquare, function=np.square)
    A_spikes = nengo.Probe(A.neurons)
    Asquare_probe = nengo.Probe(Asquare, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(
    sim.trange(),
    sim.data[input_probe],
    label="Input signal")
plt.plot(
    sim.trange(),
    sim.data[Asquare_probe],
    label="Decoded esimate")
plt.plot(
    sim.trange(),
    np.square(sim.data[input_probe]),
    label="Input signal squared")
plt.legend(loc="best", fontsize='medium')
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes])
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1503562445" href="javascript:toggle_input_1503562445()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1503562445;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1503562445 = document.getElementById("1503562445");
#                 var cell = link_1503562445;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1503562445;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1503562445 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1503562445 = cell.previousElementSibling;
#                 }
#                 input_1503562445.style.display = "none"; // hide
#
#                 toggle_input_1503562445 = function() {
#                     if (input_1503562445.style.display == "none") {
#                         input_1503562445.style.display = ""; // show
#                         link_1503562445.innerHTML = "Hide Input";
#                     } else {
#                         input_1503562445.style.display = "none"; // hide
#                         link_1503562445.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1503562445 = $("a[id='1503562445']");
#                 var cell_1503562445 = link_1503562445.parents("div.cell:first");
#                 if (cell_1503562445.length == 0) {
#                     cell_1503562445 = link_1503562445.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1503562445 = cell_1503562445.children("div.input");
#                 if (input_1503562445.length == 0) {
#                     input_1503562445 = cell_1503562445.prev("div.nbinput");
#                 }
#                 input_1503562445.hide();
#
#                 toggle_input_1503562445 = function() {
#                     if (input_1503562445.is(':hidden')) {
#                         input_1503562445.slideDown();
#                         link_1503562445[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1503562445.slideUp();
#                         link_1503562445[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Notice that the spike trains are exactly the same.
# The only difference is how we're interpreting those spikes.
# We told Nengo to compute a new set of decoders
# that estimate the function $x^2$.
#
# In general, the transformation principle
# determines how we can decode spike trains
# to compute linear and nonlinear transformations of signals
# encoded in a population of neurons.
# We can then project those transformed signals
# into another population, and repeat the process.
# Essentially, this provides a means of
# computing the neural connection weights
# to compute an arbitrary function between populations.
#
# Suppose we are representing a sine wave.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: np.sin(np.pi * t))
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1632463866" href="javascript:toggle_input_1632463866()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1632463866;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1632463866 = document.getElementById("1632463866");
#                 var cell = link_1632463866;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1632463866;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1632463866 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1632463866 = cell.previousElementSibling;
#                 }
#                 input_1632463866.style.display = "none"; // hide
#
#                 toggle_input_1632463866 = function() {
#                     if (input_1632463866.style.display == "none") {
#                         input_1632463866.style.display = ""; // show
#                         link_1632463866.innerHTML = "Hide Input";
#                     } else {
#                         input_1632463866.style.display = "none"; // hide
#                         link_1632463866.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1632463866 = $("a[id='1632463866']");
#                 var cell_1632463866 = link_1632463866.parents("div.cell:first");
#                 if (cell_1632463866.length == 0) {
#                     cell_1632463866 = link_1632463866.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1632463866 = cell_1632463866.children("div.input");
#                 if (input_1632463866.length == 0) {
#                     input_1632463866 = cell_1632463866.prev("div.nbinput");
#                 }
#                 input_1632463866.hide();
#
#                 toggle_input_1632463866 = function() {
#                     if (input_1632463866.is(':hidden')) {
#                         input_1632463866.slideDown();
#                         link_1632463866[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1632463866.slideUp();
#                         link_1632463866[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Linear transformations of that signal
# involve solving for the usual decoders,
# and scaling those decoding weights.
# Let us flip this sine wave upside down
# as it is transmitted between two populations
# (i.e. population A and population -A).

# %%
with model:
    minusA = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(A, minusA, function=lambda x: -x)
    minusA_spikes = nengo.Probe(minusA.neurons)
    minusA_probe = nengo.Probe(minusA, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(2, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.title("-A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(2, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(2, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="491153182" href="javascript:toggle_input_491153182()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_491153182;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_491153182 = document.getElementById("491153182");
#                 var cell = link_491153182;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_491153182;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_491153182 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_491153182 = cell.previousElementSibling;
#                 }
#                 input_491153182.style.display = "none"; // hide
#
#                 toggle_input_491153182 = function() {
#                     if (input_491153182.style.display == "none") {
#                         input_491153182.style.display = ""; // show
#                         link_491153182.innerHTML = "Hide Input";
#                     } else {
#                         input_491153182.style.display = "none"; // hide
#                         link_491153182.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_491153182 = $("a[id='491153182']");
#                 var cell_491153182 = link_491153182.parents("div.cell:first");
#                 if (cell_491153182.length == 0) {
#                     cell_491153182 = link_491153182.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_491153182 = cell_491153182.children("div.input");
#                 if (input_491153182.length == 0) {
#                     input_491153182 = cell_491153182.prev("div.nbinput");
#                 }
#                 input_491153182.hide();
#
#                 toggle_input_491153182 = function() {
#                     if (input_491153182.is(':hidden')) {
#                         input_491153182.slideDown();
#                         link_491153182[0].innerHTML = "Hide Input";
#                     } else {
#                         input_491153182.slideUp();
#                         link_491153182[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Nonlinear transformations involve
# solving for a new set of decoding weights.
# Let us add a third population connected
# to the second one and use it to compute $(-A)^2$.

# %%
with model:
    A_squared = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(minusA, A_squared, function=lambda x: x ** 2)
    A_squared_spikes = nengo.Probe(A_squared.neurons)
    A_squared_probe = nengo.Probe(A_squared, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 6.5))
plt.subplot(3, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.axhline(0, color='k')
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.axhline(0, color='k')
plt.title("-A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 5)
plt.plot(sim.trange(), sim.data[A_squared_probe])
plt.axhline(0, color='k')
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(3, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 6)
rasterplot(sim.trange(), sim.data[A_squared_spikes], ax)
plt.xlim(0, 2)
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1174442957" href="javascript:toggle_input_1174442957()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1174442957;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1174442957 = document.getElementById("1174442957");
#                 var cell = link_1174442957;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1174442957;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1174442957 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1174442957 = cell.previousElementSibling;
#                 }
#                 input_1174442957.style.display = "none"; // hide
#
#                 toggle_input_1174442957 = function() {
#                     if (input_1174442957.style.display == "none") {
#                         input_1174442957.style.display = ""; // show
#                         link_1174442957.innerHTML = "Hide Input";
#                     } else {
#                         input_1174442957.style.display = "none"; // hide
#                         link_1174442957.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1174442957 = $("a[id='1174442957']");
#                 var cell_1174442957 = link_1174442957.parents("div.cell:first");
#                 if (cell_1174442957.length == 0) {
#                     cell_1174442957 = link_1174442957.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1174442957 = cell_1174442957.children("div.input");
#                 if (input_1174442957.length == 0) {
#                     input_1174442957 = cell_1174442957.prev("div.nbinput");
#                 }
#                 input_1174442957.hide();
#
#                 toggle_input_1174442957 = function() {
#                     if (input_1174442957.is(':hidden')) {
#                         input_1174442957.slideDown();
#                         link_1174442957[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1174442957.slideUp();
#                         link_1174442957[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 3: Dynamics
#
# So far, we have been considering the values
# represented by ensembles as generic "signals."
# However, if we think of them instead
# as state variables in a dynamical system,
# then we can apply the methods of control theory
# or dynamic systems theory to brain models.
# Nengo automatically translates from standard dynamical systems descriptions
# to descriptions consistent with neural dynamics.
#
# In order to get interesting dynamics,
# we can connect populations recurrently (i.e., to themselves).
#
# Below is a simple harmonic oscillator
# implemented using this third principle.
# It needs is a bit of input to get it started.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: [1, 0] if t < 0.1 else [0, 0])
    oscillator = nengo.Ensemble(200, dimensions=2)
    nengo.Connection(input, oscillator)
    nengo.Connection(
        oscillator, oscillator, transform=[[1, 1], [-1, 1]], synapse=0.1)
    oscillator_probe = nengo.Probe(oscillator, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(3)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[oscillator_probe])
plt.ylim(-1.2, 1.2)
plt.xlabel('Time (s)')

plt.subplot(1, 2, 2)
plt.plot(sim.data[oscillator_probe][:, 0], sim.data[oscillator_probe][:, 1])
plt.grid()
plt.axis([-1.2, 1.2, -1.2, 1.2])
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
hide_input()
# Out:
#         <a id="1298855210" href="javascript:toggle_input_1298855210()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1298855210;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1298855210 = document.getElementById("1298855210");
#                 var cell = link_1298855210;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1298855210;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1298855210 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1298855210 = cell.previousElementSibling;
#                 }
#                 input_1298855210.style.display = "none"; // hide
#
#                 toggle_input_1298855210 = function() {
#                     if (input_1298855210.style.display == "none") {
#                         input_1298855210.style.display = ""; // show
#                         link_1298855210.innerHTML = "Hide Input";
#                     } else {
#                         input_1298855210.style.display = "none"; // hide
#                         link_1298855210.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1298855210 = $("a[id='1298855210']");
#                 var cell_1298855210 = link_1298855210.parents("div.cell:first");
#                 if (cell_1298855210.length == 0) {
#                     cell_1298855210 = link_1298855210.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1298855210 = cell_1298855210.children("div.input");
#                 if (input_1298855210.length == 0) {
#                     input_1298855210 = cell_1298855210.prev("div.nbinput");
#                 }
#                 input_1298855210.hide();
#
#                 toggle_input_1298855210 = function() {
#                     if (input_1298855210.is(':hidden')) {
#                         input_1298855210.slideDown();
#                         link_1298855210[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1298855210.slideUp();
#                         link_1298855210[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>
