# %% [markdown]
# # NEF summary
#
# The Neural Engineering Framework (NEF)
# is one set of theoretical methods that are used in
# Nengo for constructing neural models.
# The NEF is based on [Eliasmith & Anderson's (2003) book](
# https://mitpress.mit.edu/books/neural-engineering) from MIT Press.
# This notebook introduces the three main principles
# discussed in that book and implemented in Nengo.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import nengo
from nengo.dists import Uniform
from nengo.processes import WhiteSignal
from nengo.utils.ensemble import tuning_curves
from nengo.utils.ipython import hide_input
from nengo.utils.matplotlib import rasterplot


def aligned(n_neurons, radius=0.9):
    intercepts = np.linspace(-radius, radius, n_neurons)
    encoders = np.tile([[1], [-1]], (n_neurons // 2, 1))
    intercepts *= encoders[:, 0]
    return intercepts, encoders


hide_input()
# Out:
#         <a id="1772657122" href="javascript:toggle_input_1772657122()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1772657122;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1772657122 = document.getElementById("1772657122");
#                 var cell = link_1772657122;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1772657122;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1772657122 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1772657122 = cell.previousElementSibling;
#                 }
#                 input_1772657122.style.display = "none"; // hide
#
#                 toggle_input_1772657122 = function() {
#                     if (input_1772657122.style.display == "none") {
#                         input_1772657122.style.display = ""; // show
#                         link_1772657122.innerHTML = "Hide Input";
#                     } else {
#                         input_1772657122.style.display = "none"; // hide
#                         link_1772657122.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1772657122 = $("a[id='1772657122']");
#                 var cell_1772657122 = link_1772657122.parents("div.cell:first");
#                 if (cell_1772657122.length == 0) {
#                     cell_1772657122 = link_1772657122.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1772657122 = cell_1772657122.children("div.input");
#                 if (input_1772657122.length == 0) {
#                     input_1772657122 = cell_1772657122.prev("div.nbinput");
#                 }
#                 input_1772657122.hide();
#
#                 toggle_input_1772657122 = function() {
#                     if (input_1772657122.is(':hidden')) {
#                         input_1772657122.slideDown();
#                         link_1772657122[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1772657122.slideUp();
#                         link_1772657122[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 1: Representation
#
# ### Encoding
#
# Neural populations represent time-varying signals
# through their spiking responses.
# A signal is a vector of real numbers of arbitrary length.
# This example is a 1D signal going from -1 to 1 in 1 second.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1.0)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], lw=2)
plt.title("Input signal")
plt.xlabel("Time (s)")
plt.xlim(0, 1);
hide_input()
# Out:
#         <a id="656496950" href="javascript:toggle_input_656496950()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_656496950;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_656496950 = document.getElementById("656496950");
#                 var cell = link_656496950;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_656496950;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_656496950 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_656496950 = cell.previousElementSibling;
#                 }
#                 input_656496950.style.display = "none"; // hide
#
#                 toggle_input_656496950 = function() {
#                     if (input_656496950.style.display == "none") {
#                         input_656496950.style.display = ""; // show
#                         link_656496950.innerHTML = "Hide Input";
#                     } else {
#                         input_656496950.style.display = "none"; // hide
#                         link_656496950.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_656496950 = $("a[id='656496950']");
#                 var cell_656496950 = link_656496950.parents("div.cell:first");
#                 if (cell_656496950.length == 0) {
#                     cell_656496950 = link_656496950.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_656496950 = cell_656496950.children("div.input");
#                 if (input_656496950.length == 0) {
#                     input_656496950 = cell_656496950.prev("div.nbinput");
#                 }
#                 input_656496950.hide();
#
#                 toggle_input_656496950 = function() {
#                     if (input_656496950.is(':hidden')) {
#                         input_656496950.slideDown();
#                         link_656496950[0].innerHTML = "Hide Input";
#                     } else {
#                         input_656496950.slideUp();
#                         link_656496950[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# These signals drive neural populations
# based on each neuron's *tuning curve*
# (which is similar to the current-frequency curve,
# if you're familiar with that).
#
# The tuning curve describes how much
# a particular neuron will fire as a function of the input signal.

# %%
intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
with model:
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders)

# %%
with nengo.Simulator(model) as sim:
    eval_points, activities = tuning_curves(A, sim)

plt.figure()
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)");
hide_input()
# Out:
#         <a id="108430515" href="javascript:toggle_input_108430515()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_108430515;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_108430515 = document.getElementById("108430515");
#                 var cell = link_108430515;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_108430515;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_108430515 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_108430515 = cell.previousElementSibling;
#                 }
#                 input_108430515.style.display = "none"; // hide
#
#                 toggle_input_108430515 = function() {
#                     if (input_108430515.style.display == "none") {
#                         input_108430515.style.display = ""; // show
#                         link_108430515.innerHTML = "Hide Input";
#                     } else {
#                         input_108430515.style.display = "none"; // hide
#                         link_108430515.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_108430515 = $("a[id='108430515']");
#                 var cell_108430515 = link_108430515.parents("div.cell:first");
#                 if (cell_108430515.length == 0) {
#                     cell_108430515 = link_108430515.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_108430515 = cell_108430515.children("div.input");
#                 if (input_108430515.length == 0) {
#                     input_108430515 = cell_108430515.prev("div.nbinput");
#                 }
#                 input_108430515.hide();
#
#                 toggle_input_108430515 = function() {
#                     if (input_108430515.is(':hidden')) {
#                         input_108430515.slideDown();
#                         link_108430515[0].innerHTML = "Hide Input";
#                     } else {
#                         input_108430515.slideUp();
#                         link_108430515[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# We can drive these neurons with our input signal
# and observe their spiking activity over time.

# %%
with model:
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
ax = plt.subplot(1, 1, 1)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
ax.set_xlim(0, 1)
ax.set_ylabel('Neuron')
ax.set_xlabel('Time (s)');
hide_input()
# Out:
#         <a id="1194827193" href="javascript:toggle_input_1194827193()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1194827193;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1194827193 = document.getElementById("1194827193");
#                 var cell = link_1194827193;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1194827193;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1194827193 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1194827193 = cell.previousElementSibling;
#                 }
#                 input_1194827193.style.display = "none"; // hide
#
#                 toggle_input_1194827193 = function() {
#                     if (input_1194827193.style.display == "none") {
#                         input_1194827193.style.display = ""; // show
#                         link_1194827193.innerHTML = "Hide Input";
#                     } else {
#                         input_1194827193.style.display = "none"; // hide
#                         link_1194827193.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1194827193 = $("a[id='1194827193']");
#                 var cell_1194827193 = link_1194827193.parents("div.cell:first");
#                 if (cell_1194827193.length == 0) {
#                     cell_1194827193 = link_1194827193.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1194827193 = cell_1194827193.children("div.input");
#                 if (input_1194827193.length == 0) {
#                     input_1194827193 = cell_1194827193.prev("div.nbinput");
#                 }
#                 input_1194827193.hide();
#
#                 toggle_input_1194827193 = function() {
#                     if (input_1194827193.is(':hidden')) {
#                         input_1194827193.slideDown();
#                         link_1194827193[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1194827193.slideUp();
#                         link_1194827193[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ### Decoding
#
# We can estimate the input signal
# originally encoded by decoding the pattern of spikes.
# To do this, we first filter the spike train
# with a temporal filter that accounts for
# postsynaptic current (PSC) activity.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
    A = nengo.Ensemble(8, dimensions=1,
                       intercepts=intercepts,
                       max_rates=Uniform(80, 100),
                       encoders=encoders)
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

scale = 180
plt.figure()
for i in range(A.n_neurons):
    plt.plot(sim.trange(), sim.data[A_spikes][:, i] - i * scale)
plt.xlim(0, 1)
plt.ylim(scale * (-A.n_neurons + 1), scale)
plt.ylabel("Neuron")
plt.yticks(
    np.arange(scale / 1.8, (-A.n_neurons + 1) * scale, -scale),
    np.arange(A.n_neurons))
hide_input()
# Out:
#         <a id="1566712707" href="javascript:toggle_input_1566712707()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1566712707;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1566712707 = document.getElementById("1566712707");
#                 var cell = link_1566712707;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1566712707;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1566712707 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1566712707 = cell.previousElementSibling;
#                 }
#                 input_1566712707.style.display = "none"; // hide
#
#                 toggle_input_1566712707 = function() {
#                     if (input_1566712707.style.display == "none") {
#                         input_1566712707.style.display = ""; // show
#                         link_1566712707.innerHTML = "Hide Input";
#                     } else {
#                         input_1566712707.style.display = "none"; // hide
#                         link_1566712707.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1566712707 = $("a[id='1566712707']");
#                 var cell_1566712707 = link_1566712707.parents("div.cell:first");
#                 if (cell_1566712707.length == 0) {
#                     cell_1566712707 = link_1566712707.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1566712707 = cell_1566712707.children("div.input");
#                 if (input_1566712707.length == 0) {
#                     input_1566712707 = cell_1566712707.prev("div.nbinput");
#                 }
#                 input_1566712707.hide();
#
#                 toggle_input_1566712707 = function() {
#                     if (input_1566712707.is(':hidden')) {
#                         input_1566712707.slideDown();
#                         link_1566712707[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1566712707.slideUp();
#                         link_1566712707[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Then we mulitply those filtered spike trains
# with decoding weights and sum them together
# to give an estimate of the input based on the spikes.
#
# The decoding weights are determined
# by minimizing the squared difference
# between the decoded estimate and the actual input signal.

# %%
with model:
    A_probe = nengo.Probe(A, synapse=0.01)  # 10ms PSC filter

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded estimate")
plt.legend(loc="best")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="173129685" href="javascript:toggle_input_173129685()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_173129685;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_173129685 = document.getElementById("173129685");
#                 var cell = link_173129685;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_173129685;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_173129685 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_173129685 = cell.previousElementSibling;
#                 }
#                 input_173129685.style.display = "none"; // hide
#
#                 toggle_input_173129685 = function() {
#                     if (input_173129685.style.display == "none") {
#                         input_173129685.style.display = ""; // show
#                         link_173129685.innerHTML = "Hide Input";
#                     } else {
#                         input_173129685.style.display = "none"; // hide
#                         link_173129685.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_173129685 = $("a[id='173129685']");
#                 var cell_173129685 = link_173129685.parents("div.cell:first");
#                 if (cell_173129685.length == 0) {
#                     cell_173129685 = link_173129685.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_173129685 = cell_173129685.children("div.input");
#                 if (input_173129685.length == 0) {
#                     input_173129685 = cell_173129685.prev("div.nbinput");
#                 }
#                 input_173129685.hide();
#
#                 toggle_input_173129685 = function() {
#                     if (input_173129685.is(':hidden')) {
#                         input_173129685.slideDown();
#                         link_173129685[0].innerHTML = "Hide Input";
#                     } else {
#                         input_173129685.slideUp();
#                         link_173129685[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# The accuracy of the decoded estimate increases
# as the number of neurons increases.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(15, 3.5))

plt.subplot(1, 3, 1)
eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")

ax = plt.subplot(1, 3, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")

plt.subplot(1, 3, 3)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="340598491" href="javascript:toggle_input_340598491()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_340598491;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_340598491 = document.getElementById("340598491");
#                 var cell = link_340598491;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_340598491;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_340598491 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_340598491 = cell.previousElementSibling;
#                 }
#                 input_340598491.style.display = "none"; // hide
#
#                 toggle_input_340598491 = function() {
#                     if (input_340598491.style.display == "none") {
#                         input_340598491.style.display = ""; // show
#                         link_340598491.innerHTML = "Hide Input";
#                     } else {
#                         input_340598491.style.display = "none"; // hide
#                         link_340598491.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_340598491 = $("a[id='340598491']");
#                 var cell_340598491 = link_340598491.parents("div.cell:first");
#                 if (cell_340598491.length == 0) {
#                     cell_340598491 = link_340598491.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_340598491 = cell_340598491.children("div.input");
#                 if (input_340598491.length == 0) {
#                     input_340598491 = cell_340598491.prev("div.nbinput");
#                 }
#                 input_340598491.hide();
#
#                 toggle_input_340598491 = function() {
#                     if (input_340598491.is(':hidden')) {
#                         input_340598491.slideDown();
#                         link_340598491[0].innerHTML = "Hide Input";
#                     } else {
#                         input_340598491.slideUp();
#                         link_340598491[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Any smooth signal can be encoded and decoded.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="529315320" href="javascript:toggle_input_529315320()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_529315320;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_529315320 = document.getElementById("529315320");
#                 var cell = link_529315320;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_529315320;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_529315320 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_529315320 = cell.previousElementSibling;
#                 }
#                 input_529315320.style.display = "none"; // hide
#
#                 toggle_input_529315320 = function() {
#                     if (input_529315320.style.display == "none") {
#                         input_529315320.style.display = ""; // show
#                         link_529315320.innerHTML = "Hide Input";
#                     } else {
#                         input_529315320.style.display = "none"; // hide
#                         link_529315320.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_529315320 = $("a[id='529315320']");
#                 var cell_529315320 = link_529315320.parents("div.cell:first");
#                 if (cell_529315320.length == 0) {
#                     cell_529315320 = link_529315320.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_529315320 = cell_529315320.children("div.input");
#                 if (input_529315320.length == 0) {
#                     input_529315320 = cell_529315320.prev("div.nbinput");
#                 }
#                 input_529315320.hide();
#
#                 toggle_input_529315320 = function() {
#                     if (input_529315320.is(':hidden')) {
#                         input_529315320.slideDown();
#                         link_529315320[0].innerHTML = "Hide Input";
#                     } else {
#                         input_529315320.slideUp();
#                         link_529315320[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 2: Transformation
#
# Encoding and decoding allow us to encode signals over time,
# and decode transformations of those signals.
#
# In fact, we can decode arbitrary transformations of the input signal,
# not just the signal itself (as in the previous example).
#
# Let's decode the square of our white noise input.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input, )
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    Asquare = nengo.Node(size_in=1)
    nengo.Connection(input, A)
    nengo.Connection(A, Asquare, function=np.square)
    A_spikes = nengo.Probe(A.neurons)
    Asquare_probe = nengo.Probe(Asquare, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(
    sim.trange(),
    sim.data[input_probe],
    label="Input signal")
plt.plot(
    sim.trange(),
    sim.data[Asquare_probe],
    label="Decoded esimate")
plt.plot(
    sim.trange(),
    np.square(sim.data[input_probe]),
    label="Input signal squared")
plt.legend(loc="best", fontsize='medium')
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes])
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="423085461" href="javascript:toggle_input_423085461()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_423085461;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_423085461 = document.getElementById("423085461");
#                 var cell = link_423085461;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_423085461;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_423085461 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_423085461 = cell.previousElementSibling;
#                 }
#                 input_423085461.style.display = "none"; // hide
#
#                 toggle_input_423085461 = function() {
#                     if (input_423085461.style.display == "none") {
#                         input_423085461.style.display = ""; // show
#                         link_423085461.innerHTML = "Hide Input";
#                     } else {
#                         input_423085461.style.display = "none"; // hide
#                         link_423085461.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_423085461 = $("a[id='423085461']");
#                 var cell_423085461 = link_423085461.parents("div.cell:first");
#                 if (cell_423085461.length == 0) {
#                     cell_423085461 = link_423085461.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_423085461 = cell_423085461.children("div.input");
#                 if (input_423085461.length == 0) {
#                     input_423085461 = cell_423085461.prev("div.nbinput");
#                 }
#                 input_423085461.hide();
#
#                 toggle_input_423085461 = function() {
#                     if (input_423085461.is(':hidden')) {
#                         input_423085461.slideDown();
#                         link_423085461[0].innerHTML = "Hide Input";
#                     } else {
#                         input_423085461.slideUp();
#                         link_423085461[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Notice that the spike trains are exactly the same.
# The only difference is how we're interpreting those spikes.
# We told Nengo to compute a new set of decoders
# that estimate the function $x^2$.
#
# In general, the transformation principle
# determines how we can decode spike trains
# to compute linear and nonlinear transformations of signals
# encoded in a population of neurons.
# We can then project those transformed signals
# into another population, and repeat the process.
# Essentially, this provides a means of
# computing the neural connection weights
# to compute an arbitrary function between populations.
#
# Suppose we are representing a sine wave.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: np.sin(np.pi * t))
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1988649947" href="javascript:toggle_input_1988649947()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1988649947;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1988649947 = document.getElementById("1988649947");
#                 var cell = link_1988649947;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1988649947;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1988649947 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1988649947 = cell.previousElementSibling;
#                 }
#                 input_1988649947.style.display = "none"; // hide
#
#                 toggle_input_1988649947 = function() {
#                     if (input_1988649947.style.display == "none") {
#                         input_1988649947.style.display = ""; // show
#                         link_1988649947.innerHTML = "Hide Input";
#                     } else {
#                         input_1988649947.style.display = "none"; // hide
#                         link_1988649947.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1988649947 = $("a[id='1988649947']");
#                 var cell_1988649947 = link_1988649947.parents("div.cell:first");
#                 if (cell_1988649947.length == 0) {
#                     cell_1988649947 = link_1988649947.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1988649947 = cell_1988649947.children("div.input");
#                 if (input_1988649947.length == 0) {
#                     input_1988649947 = cell_1988649947.prev("div.nbinput");
#                 }
#                 input_1988649947.hide();
#
#                 toggle_input_1988649947 = function() {
#                     if (input_1988649947.is(':hidden')) {
#                         input_1988649947.slideDown();
#                         link_1988649947[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1988649947.slideUp();
#                         link_1988649947[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Linear transformations of that signal
# involve solving for the usual decoders,
# and scaling those decoding weights.
# Let us flip this sine wave upside down
# as it is transmitted between two populations
# (i.e. population A and population -A).

# %%
with model:
    minusA = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(A, minusA, function=lambda x: -x)
    minusA_spikes = nengo.Probe(minusA.neurons)
    minusA_probe = nengo.Probe(minusA, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(2, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.title("-A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(2, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(2, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1103055626" href="javascript:toggle_input_1103055626()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1103055626;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1103055626 = document.getElementById("1103055626");
#                 var cell = link_1103055626;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1103055626;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1103055626 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1103055626 = cell.previousElementSibling;
#                 }
#                 input_1103055626.style.display = "none"; // hide
#
#                 toggle_input_1103055626 = function() {
#                     if (input_1103055626.style.display == "none") {
#                         input_1103055626.style.display = ""; // show
#                         link_1103055626.innerHTML = "Hide Input";
#                     } else {
#                         input_1103055626.style.display = "none"; // hide
#                         link_1103055626.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1103055626 = $("a[id='1103055626']");
#                 var cell_1103055626 = link_1103055626.parents("div.cell:first");
#                 if (cell_1103055626.length == 0) {
#                     cell_1103055626 = link_1103055626.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1103055626 = cell_1103055626.children("div.input");
#                 if (input_1103055626.length == 0) {
#                     input_1103055626 = cell_1103055626.prev("div.nbinput");
#                 }
#                 input_1103055626.hide();
#
#                 toggle_input_1103055626 = function() {
#                     if (input_1103055626.is(':hidden')) {
#                         input_1103055626.slideDown();
#                         link_1103055626[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1103055626.slideUp();
#                         link_1103055626[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Nonlinear transformations involve
# solving for a new set of decoding weights.
# Let us add a third population connected
# to the second one and use it to compute $(-A)^2$.

# %%
with model:
    A_squared = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(minusA, A_squared, function=lambda x: x ** 2)
    A_squared_spikes = nengo.Probe(A_squared.neurons)
    A_squared_probe = nengo.Probe(A_squared, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 6.5))
plt.subplot(3, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.axhline(0, color='k')
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.axhline(0, color='k')
plt.title("-A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 5)
plt.plot(sim.trange(), sim.data[A_squared_probe])
plt.axhline(0, color='k')
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(3, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 6)
rasterplot(sim.trange(), sim.data[A_squared_spikes], ax)
plt.xlim(0, 2)
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="904645734" href="javascript:toggle_input_904645734()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_904645734;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_904645734 = document.getElementById("904645734");
#                 var cell = link_904645734;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_904645734;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_904645734 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_904645734 = cell.previousElementSibling;
#                 }
#                 input_904645734.style.display = "none"; // hide
#
#                 toggle_input_904645734 = function() {
#                     if (input_904645734.style.display == "none") {
#                         input_904645734.style.display = ""; // show
#                         link_904645734.innerHTML = "Hide Input";
#                     } else {
#                         input_904645734.style.display = "none"; // hide
#                         link_904645734.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_904645734 = $("a[id='904645734']");
#                 var cell_904645734 = link_904645734.parents("div.cell:first");
#                 if (cell_904645734.length == 0) {
#                     cell_904645734 = link_904645734.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_904645734 = cell_904645734.children("div.input");
#                 if (input_904645734.length == 0) {
#                     input_904645734 = cell_904645734.prev("div.nbinput");
#                 }
#                 input_904645734.hide();
#
#                 toggle_input_904645734 = function() {
#                     if (input_904645734.is(':hidden')) {
#                         input_904645734.slideDown();
#                         link_904645734[0].innerHTML = "Hide Input";
#                     } else {
#                         input_904645734.slideUp();
#                         link_904645734[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 3: Dynamics
#
# So far, we have been considering the values
# represented by ensembles as generic "signals."
# However, if we think of them instead
# as state variables in a dynamical system,
# then we can apply the methods of control theory
# or dynamic systems theory to brain models.
# Nengo automatically translates from standard dynamical systems descriptions
# to descriptions consistent with neural dynamics.
#
# In order to get interesting dynamics,
# we can connect populations recurrently (i.e., to themselves).
#
# Below is a simple harmonic oscillator
# implemented using this third principle.
# It needs is a bit of input to get it started.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: [1, 0] if t < 0.1 else [0, 0])
    oscillator = nengo.Ensemble(200, dimensions=2)
    nengo.Connection(input, oscillator)
    nengo.Connection(
        oscillator, oscillator, transform=[[1, 1], [-1, 1]], synapse=0.1)
    oscillator_probe = nengo.Probe(oscillator, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(3)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[oscillator_probe])
plt.ylim(-1.2, 1.2)
plt.xlabel('Time (s)')

plt.subplot(1, 2, 2)
plt.plot(sim.data[oscillator_probe][:, 0], sim.data[oscillator_probe][:, 1])
plt.grid()
plt.axis([-1.2, 1.2, -1.2, 1.2])
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
hide_input()
# Out:
#         <a id="260450025" href="javascript:toggle_input_260450025()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_260450025;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_260450025 = document.getElementById("260450025");
#                 var cell = link_260450025;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_260450025;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_260450025 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_260450025 = cell.previousElementSibling;
#                 }
#                 input_260450025.style.display = "none"; // hide
#
#                 toggle_input_260450025 = function() {
#                     if (input_260450025.style.display == "none") {
#                         input_260450025.style.display = ""; // show
#                         link_260450025.innerHTML = "Hide Input";
#                     } else {
#                         input_260450025.style.display = "none"; // hide
#                         link_260450025.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_260450025 = $("a[id='260450025']");
#                 var cell_260450025 = link_260450025.parents("div.cell:first");
#                 if (cell_260450025.length == 0) {
#                     cell_260450025 = link_260450025.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_260450025 = cell_260450025.children("div.input");
#                 if (input_260450025.length == 0) {
#                     input_260450025 = cell_260450025.prev("div.nbinput");
#                 }
#                 input_260450025.hide();
#
#                 toggle_input_260450025 = function() {
#                     if (input_260450025.is(':hidden')) {
#                         input_260450025.slideDown();
#                         link_260450025[0].innerHTML = "Hide Input";
#                     } else {
#                         input_260450025.slideUp();
#                         link_260450025[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>
